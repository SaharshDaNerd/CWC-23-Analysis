# %%
import requests
import pandas as pd

# %%
response = requests.get(
    'https://api.cricapi.com/v1/players_info?apikey=6b1a7428-19f5-479f-a2a1-00201cbfd454&id=c61d247d-7f77-452c-b495-2813a9cd0ac4')

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
data
# Out:
# {'apikey': '6b1a7428-19f5-479f-a2a1-00201cbfd454',
#  'data': {'id': 'c61d247d-7f77-452c-b495-2813a9cd0ac4',
#   'name': 'Virat Kohli',
#   'dateOfBirth': '1988-11-05T00:00:00',
#   'role': 'Batsman',
#   'battingStyle': 'Right Handed Bat',
#   'bowlingStyle': 'Right-arm medium',
#   'placeOfBirth': 'Delhi',
#   'country': 'India',
#   'playerImg': 'https://h.cricapi.com/img/players/c61d247d-7f77-452c-b495-2813a9cd0ac4.jpg',
#   'stats': [{'fn': 'batting',
#     'matchtype': 'test',
#     'stat': 'm',
#     'value': '123'},
#    {'fn': 'batting', 'matchtype': 'test', 'stat': 'inn', 'value': '210'},
#    {'fn': 'batting', 'matchtype': 'test', 'stat': 'no', 'value': '13'},
#    {'fn': 'batting', 'matchtype': 'test', 'stat': 'runs', 'value': '9230'},
#    {'fn': 'batting', 'matchtype': 'test', 'stat': 'hs', 'value': '254'},
#    {'fn': 'batting', 'matchtype': 'test', 'stat': 'avg', 'value': '46.85'},
#    {'fn': 'batting', 'matchtype': 'test', 'stat': 'bf', 'value': '16608'},
# ...
